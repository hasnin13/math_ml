# %%
print("HELLO WORLD!!!ZEHR PI KE MAR JAYUUU :')")
# Out:
# HELLO WORLD!!!ZEHR PI KE MAR JAYUUU :')

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
import pandas as pd

# %%
date = {
    'age': [25, 30, 35],
    'salary': [50000, 60000, 70000],
}
df = pd.DataFrame(date)
df
# Out:
#    age  salary
# 0   25   50000
# 1   30   60000
# 2   35   70000

# %%
import matplotlib.pyplot as plt
import numpy as np

#Use a clean plot style
plt.style.use('_mpl-gallery')

#Make data for a double helix
n = 100
theta = np.linspace(0, 4 * np.pi, n)  # more turns for visibility
x1 = np.cos(theta)
y1 = np.sin(theta)
z1 = np.linspace(0, 2, n)

x2 = np.cos(theta + np.pi)
y2 = np.sin(theta + np.pi)
z2 = z1

#Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#Plot the two helices
ax.plot(x1, y1, z1, linewidth=2, color='C0')
ax.plot(x2, y2, z2, linewidth=2, color='C1')

#Turn off axis labels
ax.set(xticklabels=[], yticklabels=[], zticklabels=[])

plt.show()

# %%
from sympy import *
x = symbols('x')
f = 2*x + 1
plot(f)

# %%
type(arr)
# Out:
# numpy.ndarray
